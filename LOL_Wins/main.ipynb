# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# plt.style.use('seaborn')
sns.set(font_scale = 2.5)

import missingno as msno

import warnings
warnings.filterwarnings('ignore')

# %%
df_test = pd.read_csv("E:\\GithubProjects\\KagglePractice\\LOL_Wins\\high_diamond_ranked_10min.csv")

df_test = df_test.fillna(df_test.mean())

# %%
df_test.agg(lambda x: sum(x.isnull()) / x.shape[0])
# Out:
# gameId                          0.0
# blueWins                        0.0
# blueWardsPlaced                 0.0
# blueWardsDestroyed              0.0
# blueFirstBlood                  0.0
# blueKills                       0.0
# blueDeaths                      0.0
# blueAssists                     0.0
# blueEliteMonsters               0.0
# blueDragons                     0.0
# blueHeralds                     0.0
# blueTowersDestroyed             0.0
# blueTotalGold                   0.0
# blueAvgLevel                    0.0
# blueTotalExperience             0.0
# blueTotalMinionsKilled          0.0
# blueTotalJungleMinionsKilled    0.0
# blueGoldDiff                    0.0
# blueExperienceDiff              0.0
# blueCSPerMin                    0.0
# blueGoldPerMin                  0.0
# redWardsPlaced                  0.0
# redWardsDestroyed               0.0
# redFirstBlood                   0.0
# redKills                        0.0
# redDeaths                       0.0
# ...

# %%
DataCount = df_test['blueWins'].count()
BlueWins = len(df_test.loc[df_test['blueWins'] == 1])

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))

sns.kdeplot(df_test[df_test['blueWins'] == 1]['blueKills'], ax=ax)
sns.kdeplot(df_test[df_test['blueWins'] == 0]['redKills'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))

sns.kdeplot(df_test[df_test['blueWins'] == 1]['blueKills'], ax=ax)
sns.kdeplot(df_test[df_test['blueWins'] == 1]['redKills'], ax=ax)
sns.kdeplot(df_test[df_test['blueWins'] == 0]['blueKills'], ax=ax)
sns.kdeplot(df_test[df_test['blueWins'] == 0]['redKills'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 5))

sns.kdeplot(df_test[df_test['blueWins'] == 1][df_test['blueWardsPlaced'] < 70]['blueWardsPlaced'], ax=ax[0])
sns.kdeplot(df_test[df_test['blueWins'] == 1][df_test['redWardsPlaced'] < 70]['redWardsPlaced'], ax=ax[0])
# 70개 아래만
plt.legend(['blue', 'red'])
# ax[0].set_xticks(range(0, 300, 70))


sns.kdeplot(df_test[df_test['blueWins'] == 1]['blueKills'], ax=ax[1])
sns.kdeplot(df_test[df_test['blueWins'] == 1]['redKills'], ax=ax[1])

sns.kdeplot(df_test[df_test['blueWins'] == 1]['blueDeaths'], ax=ax[1])
sns.kdeplot(df_test[df_test['blueWins'] == 1]['redDeaths'], ax=ax[1])
ax[1].set_xticks(range(0, 30, 5))
plt.legend(['blue', 'red', 'bluedeath', 'reddeath'])
plt.show()

# %%
f, ax = plt.subplots(1, 1, figsize=(10 ,10))
g = sns.distplot(df_test[df_test['blueWins'] == 1]['blueTotalGold'], color='b', label=f"blue", ax = ax)
g = g.legend(loc='best')
g = sns.distplot(df_test[df_test['blueWins'] == 1]['redTotalGold'], color='r', label=f"red", ax = ax)
g = g.legend(loc='best')

# %%
f, ax = plt.subplots(1, 1, figsize=(10 ,10))

A = df_test[df_test['blueWins'] == 1]['blueWardsPlaced']
B = df_test[df_test['blueWins'] == 1]['redWardsPlaced']

g = sns.distplot(np.log(A), color='b', ax = ax, label = 'Blue ward - log')
g = g.legend(loc='best')
g = sns.distplot(np.log(B), color='r', ax = ax, label = 'Red ward - log')
g = g.legend(loc='best')

# g = sns.distplot(A, color='b', ax = ax, label = 'Blue ward')
# g = g.legend(loc='best')
# g = sns.distplot(B, color='r', ax = ax, label = 'Red ward')
# g = g.legend(loc='best')

# %%
f, ax = plt.subplots(1, 2, figsize=(10 ,10))
g = sns.distplot(df_test[df_test['blueWins'] == 1]['blueDragons'], color='b', ax = ax[0], label = 'Blue win - FullData')
g = g.legend(loc='best')
g = sns.distplot(df_test[df_test['blueWins'] == 0]['blueDragons'], color='b', ax = ax[1], label = 'Blue Lose - FullData')
g = g.legend(loc='best')

# %%
f, ax = plt.subplots(1, 1, figsize=(10 ,10))
g = sns.countplot(df_test[df_test['blueWins'] == 1]['blueFirstBlood'], color='b', ax = ax, label = 'Blue win - FullData')
g = g.legend(loc='best')

# %%
f, ax = plt.subplots(1, 1, figsize=(10 ,10))
A = df_test[df_test['blueWins'] == 1]['blueTotalMinionsKilled']
B = df_test[df_test['blueWins'] == 0]['blueTotalMinionsKilled']
g = sns.distplot(A, color='b', ax = ax, label = 'Blue win - FullData')
g = g.legend(loc='best')
g = sns.distplot(B, color='r', ax = ax, label = 'Blue Lose - FullData')
g = g.legend(loc='best')

# %%
f, ax = plt.subplots(1, 1, figsize=(10 ,10))
A = df_test[df_test['blueWins'] == 1]['blueTotalGold']
B = df_test[df_test['blueWins'] == 1]['redTotalGold']
g = sns.distplot(np.log(A), color='b', ax = ax, label = 'Blue money')
g = g.legend(loc='best')
g = sns.distplot(np.log(B), color='r', ax = ax, label = 'Red money')
g = g.legend(loc='best')

# %%
f, ax = plt.subplots(1, 1, figsize=(10 ,10))
A = df_test[df_test['blueWins'] == 1]['blueAssists']
B = df_test[df_test['blueWins'] == 1]['redAssists']
g = sns.distplot(A, color='b', ax = ax, label = 'Blue assist')
g = g.legend(loc='best')
g = sns.distplot(B, color='r', ax = ax, label = 'Red assist')
g = g.legend(loc='best')

# %%
f, ax = plt.subplots(1, 1, figsize=(10 ,10))
A = df_test[df_test['blueWins'] == 1]['blueHeralds']
B = df_test[df_test['blueWins'] == 1]['redHeralds']
g = sns.distplot(A, color='b', ax = ax, label = 'Blue assist')
g = g.legend(loc='best')
g = sns.distplot(B, color='r', ax = ax, label = 'Red assist')
g = g.legend(loc='best')

# %%
f, ax = plt.subplots(1, 1, figsize=(10 ,10))
A = df_test[df_test['blueWins'] == 1]['blueAvgLevel']
B = df_test[df_test['blueWins'] == 1]['redAvgLevel']
g = sns.distplot(A, color='b', ax = ax, label = 'Blue assist')
g = g.legend(loc='best')
g = sns.distplot(B, color='r', ax = ax, label = 'Red assist')
g = g.legend(loc='best')

# %%
f, ax = plt.subplots(1, 1, figsize=(10 ,10))
A = df_test[df_test['blueWins'] == 1]['blueGoldPerMin']
B = df_test[df_test['blueWins'] == 1]['redGoldPerMin']
g = sns.distplot(A, color='b', ax = ax, label = 'Blue assist')
g = g.legend(loc='best')
g = sns.distplot(B, color='r', ax = ax, label = 'Red assist')
g = g.legend(loc='best')
