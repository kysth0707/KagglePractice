# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# plt.style.use('seaborn')
sns.set(font_scale = 2.5)

import missingno as msno

import warnings
warnings.filterwarnings('ignore')

# %%
df_test = pd.read_csv("E:\\GithubProjects\\KagglePractice\\University\\gpascore.csv")

print(df_test.isnull().any())
df_test = df_test.dropna(axis=0)
print(df_test.isnull().any())
# Out:
# admit    False
# gre       True
# gpa      False
# rank     False
# dtype: bool
# admit    False
# gre      False
# gpa      False
# rank     False
# dtype: bool

# %%
print(df_test['admit'].values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 print(df_test['admit'].values)
#
# NameError: name 'df_test' is not defined

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13538470365438131192
# xla_global_id: -1
# ]

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))

sns.kdeplot(df_test['admit'], ax=ax)
sns.kdeplot(df_test['gpa'], ax=ax)
sns.kdeplot(df_test['rank'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))

sns.kdeplot(df_test['gre'], ax=ax)
plt.show()
