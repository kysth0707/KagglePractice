# %%
import matplotlib.pyplot as plt
import HelmetGenerator
import os
import cv2 as cv

# %%
TopPos = r'E:\GithubProjects\KagglePractice\HelmetDetection\Datasets\cleared'
ImagePosList = os.listdir(TopPos)

# %%
HelmetPos = r'E:\GithubProjects\KagglePractice\HelmetDetection\HelmetImage.png'

# %%
SaveTopPos = r'E:\GithubProjects\KagglePractice\HelmetDetection\Datasets\clearedwithhelmet'

# %%
HelmetImage = HelmetGenerator.GetHelmetImage(fr"{TopPos}\{ImagePosList[0]}", HelmetPos)
plt.imshow(HelmetImage)

# %%
HelmetImage = HelmetGenerator.GetHelmetImage(fr"{TopPos}\{ImagePosList[0]}", HelmetPos)
cv.imwrite(fr"{SaveTopPos}\{ImagePosList[0]}", cv.cvtColor(HelmetImage, cv.COLOR_RGB2BGR))
# Out:
# True

# %%
for i in range(10):
	print(f"\r{i}ㅁㄴㅇㄹ",end="")
# Out:
# 9ㅁㄴㅇㄹ

# %%
for i, ImagePos in enumerate(ImagePosList):
	try:
		HelmetImage = HelmetGenerator.GetHelmetImage(fr"{TopPos}\{ImagePos}", HelmetPos)
		cv.imwrite(fr"{SaveTopPos}\{ImagePos}", cv.cvtColor(HelmetImage, cv.COLOR_RGB2BGR))
		print(f"\r{i} / {len(ImagePosList)} 완료!",end="")
	except:
		print(f"오류 at {i}")
		print(f"\r{i} / {len(ImagePosList)} 완료!",end="")
# Out:
# 69 / 686 완료!오류 at 70
# 70 / 686 완료!오류 at 71
# 88 / 686 완료!오류 at 89
# 168 / 686 완료!오류 at 169
# 169 / 686 완료!오류 at 170
# 188 / 686 완료!오류 at 189
# 222 / 686 완료!오류 at 223
# 236 / 686 완료!오류 at 237
# 241 / 686 완료!오류 at 242
# 261 / 686 완료!오류 at 262
# 265 / 686 완료!오류 at 266
# 269 / 686 완료!오류 at 270
# 292 / 686 완료!오류 at 293
# 306 / 686 완료!오류 at 307
# 313 / 686 완료!오류 at 314
# 320 / 686 완료!오류 at 321
# 331 / 686 완료!오류 at 332
# 381 / 686 완료!오류 at 382
# 399 / 686 완료!오류 at 400
# 407 / 686 완료!오류 at 408
# 411 / 686 완료!오류 at 412
# 412 / 686 완료!오류 at 413
# 413 / 686 완료!오류 at 414
# 456 / 686 완료!오류 at 457
# 457 / 686 완료!오류 at 458
# 458 / 686 완료!오류 at 459
# 483 / 686 완료!오류 at 484
# 484 / 686 완료!오류 at 485
# 485 / 686 완료!오류 at 486
# 487 / 686 완료!오류 at 488
# 488 / 686 완료!오류 at 489
# 535 / 686 완료!오류 at 536
# 598 / 686 완료!오류 at 599
# 599 / 686 완료!오류 at 600
# 614 / 686 완료!오류 at 615
# 615 / 686 완료!오류 at 616
# 616 / 686 완료!오류 at 617
# 617 / 686 완료!오류 at 618
# 618 / 686 완료!오류 at 619
# 626 / 686 완료!오류 at 627
# ...

# %% [markdown]
# 626/686 Converted

# %%
TopPos = r'E:\GithubProjects\KagglePractice\HelmetDetection\RawDatasets'
ImagePosList = os.listdir(TopPos)

# %%
SaveTopPos = r'E:\GithubProjects\KagglePractice\HelmetDetection\NotClearDatasets\with_helmet'

# %%
for i, ImagePos in enumerate(ImagePosList):
	try:
		HelmetImage = HelmetGenerator.GetHelmetImage(fr"{TopPos}\{ImagePos}", HelmetPos)
		cv.imwrite(fr"{SaveTopPos}\{ImagePos}", cv.cvtColor(HelmetImage, cv.COLOR_RGB2BGR))
		print(f"\r{i} / {len(ImagePosList)} 완료!",end="")
	except:
		print(f"오류 at {i}")
		print(f"\r{i} / {len(ImagePosList)} 완료!",end="")
# Out:
# 69 / 686 완료!오류 at 70
# 70 / 686 완료!오류 at 71
# 88 / 686 완료!오류 at 89
# 122 / 686 완료!오류 at 123
# 161 / 686 완료!오류 at 162
# 168 / 686 완료!오류 at 169
# 169 / 686 완료!오류 at 170
# 187 / 686 완료!오류 at 188
# 188 / 686 완료!오류 at 189
# 222 / 686 완료!오류 at 223
# 236 / 686 완료!오류 at 237
# 241 / 686 완료!오류 at 242
# 265 / 686 완료!오류 at 266
# 269 / 686 완료!오류 at 270
# 292 / 686 완료!오류 at 293
# 306 / 686 완료!오류 at 307
# 313 / 686 완료!오류 at 314
# 320 / 686 완료!오류 at 321
# 331 / 686 완료!오류 at 332
# 381 / 686 완료!오류 at 382
# 399 / 686 완료!오류 at 400
# 407 / 686 완료!오류 at 408
# 411 / 686 완료!오류 at 412
# 412 / 686 완료!오류 at 413
# 413 / 686 완료!오류 at 414
# 456 / 686 완료!오류 at 457
# 457 / 686 완료!오류 at 458
# 458 / 686 완료!오류 at 459
# 483 / 686 완료!오류 at 484
# 484 / 686 완료!오류 at 485
# 485 / 686 완료!오류 at 486
# 487 / 686 완료!오류 at 488
# 488 / 686 완료!오류 at 489
# 535 / 686 완료!오류 at 536
# 561 / 686 완료!오류 at 562
# 567 / 686 완료!오류 at 568
# 568 / 686 완료!오류 at 569
# 587 / 686 완료!오류 at 588
# 598 / 686 완료!오류 at 599
# 599 / 686 완료!오류 at 600
# ...
