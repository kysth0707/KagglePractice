# %%
import matplotlib.pyplot as plt
import HelmetGenerator
import os

# %%
TopPos = r'E:\GithubProjects\KagglePractice\HelmetDetection\Datasets\without_helmet'
ImagePosList = os.listdir(TopPos)

# %%
HelmetPos = r'E:\GithubProjects\KagglePractice\HelmetDetection\HelmetImage.png'

# %%
HelmetImage = HelmetGenerator.GetHelmetImage(fr"{TopPos}\{ImagePosList[3]}", HelmetPos)
plt.imshow(HelmetImage)

# %% [markdown]
# good

# %%
for i in range(10):
	plt.subplot(1, 10, i + 1)
	HelmetImage = HelmetGenerator.GetHelmetImage(fr"{TopPos}\{ImagePosList[i]}", HelmetPos)
	plt.imshow(HelmetImage)
plt.show()

# %% [markdown]
# 이 정도면 잘 된 것 같다!
